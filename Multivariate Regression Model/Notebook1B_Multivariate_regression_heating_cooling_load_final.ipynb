# %% [markdown]
# ## Notebook 1B: Multivariate regression of energy consumption

# %% [markdown]
# **1. Prepare Problem**

# %%
# a) Load libraries
import pandas as pd
from pandas import set_option
from pandas import DataFrame

import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow import keras
from keras.callbacks import EarlyStopping
from scikeras.wrappers import KerasRegressor
from tensorflow.keras.models import Sequential
from keras.layers import BatchNormalization, Dropout, Dense

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import *
from sklearn.ensemble import *
from sklearn.svm import SVR
from sklearn.multioutput import MultiOutputRegressor
from sklearn.model_selection import KFold
from sklearn.model_selection import learning_curve
from sklearn.model_selection import cross_val_score

from pickle import dump

# %%
import sklearn
print('scikit-learn version:', sklearn.__version__)
# Out:
# scikit-learn version: 1.5.2

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
# b) Load dataset
# Load and view each file in the dataset
data = pd.read_csv('EPB_data.csv', header=0)
print(data.shape)
display(data.head(10))
print(data.dtypes)
# Out:
# (768, 8)
#    Relative Compactness  Surface Area  Roof Area  Overall Height  Orientation  \
# 0                  0.98         514.5     110.25             7.0            2
# 1                  0.98         514.5     110.25             7.0            3
# 2                  0.98         514.5     110.25             7.0            4
# 3                  0.98         514.5     110.25             7.0            5
# 4                  0.90         563.5     122.50             7.0            2
# 5                  0.90         563.5     122.50             7.0            3
# 6                  0.90         563.5     122.50             7.0            4
# 7                  0.90         563.5     122.50             7.0            5
# 8                  0.86         588.0     147.00             7.0            2
# 9                  0.86         588.0     147.00             7.0            3
#
#    Glazing Area  Glazing Area Distribution  Heating Load
# 0           0.0                          0         15.55
# 1           0.0                          0         15.55
# 2           0.0                          0         15.55
# 3           0.0                          0         15.55
# 4           0.0                          0         20.84
# 5           0.0                          0         21.46
# 6           0.0                          0         20.71
# 7           0.0                          0         19.68
# 8           0.0                          0         19.50
# 9           0.0                          0         19.95
# Relative Compactness         float64
# Surface Area                 float64
# Roof Area                    float64
# Overall Height               float64
# Orientation                    int64
# Glazing Area                 float64
# Glazing Area Distribution      int64
# Heating Load                 float64
# dtype: object

# %% [markdown]
# One of the approach in optimizing building energy efficiency is to minimize total energy consumption, which is the sum of heating and cooling.

# %%
# Define features and label
X = data.drop(columns=['Heating Load'], axis = 1)
y = data[['Heating Load']]
print(X.shape, y.shape)
# Out:
# (768, 7) (768, 1)

# %% [markdown]
# **2. Dataset summary**

# %%
# a) Descriptive statistics
set_option("display.precision", 3)
print(data.describe())
# Out:
#        Relative Compactness  Surface Area  Roof Area  Overall Height  \
# count               768.000       768.000    768.000         768.000
# mean                  0.764       671.708    176.604           5.250
# std                   0.106        88.086     45.166           1.751
# min                   0.620       514.500    110.250           3.500
# 25%                   0.682       606.375    140.875           3.500
# 50%                   0.750       673.750    183.750           5.250
# 75%                   0.830       741.125    220.500           7.000
# max                   0.980       808.500    220.500           7.000
#
#        Orientation  Glazing Area  Glazing Area Distribution  Heating Load
# count      768.000       768.000                    768.000       768.000
# mean         3.500         0.234                      2.812        22.307
# std          1.119         0.133                      1.551        10.090
# min          2.000         0.000                      0.000         6.010
# 25%          2.750         0.100                      1.750        12.992
# 50%          3.500         0.250                      3.000        18.950
# 75%          4.250         0.400                      4.000        31.668
# max          5.000         0.400                      5.000        43.100

# %%
# checking categorical features
cat_features = data.select_dtypes(include='O').keys()
# display variabels
cat_features
# Out:
# Index([], dtype='object')

# %%
# b) Data visualizations
# Box and Whisker Plots of a few features

plt.rcParams["figure.figsize"] = [10, 6]
plt.rcParams["figure.autolayout"] = True

raw_plot = pd.DataFrame(data)
raw_plot.plot(kind='box', subplots=True, layout=(4,3), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# We can see the data skewed to high values in relative compactness, roof area, glazing area, and cooling load.

# %%
# create the stack bar chart of Heating and Cooling Load
fig, ax = plt.subplots()
ax.bar(np.arange(len(data['Heating Load'])), data['Heating Load'], label='Heating Load')

# add labels, title and legend
ax.set_xlabel('Number of Samples')
ax.set_ylabel('Energy Consumption (kWh)')
ax.set_title('bill')
ax.legend()

# show the plot
plt.show()

# %% [markdown]
# The data displays a cyclical pattern that may have resulted from the measurements taken on weekdays (with longer hours) and weekends.

# %%
# Create a figure with subplots
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(12, 8))

# Flatten the axes array to simplify plotting
axes = axes.flatten()

# Loop through each feature and create a density plot
for i, feature in enumerate(raw_plot.columns):
    sns.kdeplot(raw_plot[feature], ax=axes[i], color='steelblue', fill=True)
    axes[i].set_title(feature)

# Adjust the layout and spacing of the subplots
fig.tight_layout()

plt.show()

# %% [markdown]
# The dataset seems to be complex as most of features exhibit non-Gaussian distributions, except for the Surface Area. There are several factors that could cause non-Gaussian distributions, including outliers, measurement errors, or the inherent characteristics of the building designs.

# %%
# correlation matrix between all pairs of attributes
corr_matrix = data.corr(method='pearson')

# Create a heatmap using seaborn
fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr_matrix, vmin=-1, vmax=1, annot=True, cmap="coolwarm", ax=ax)

plt.show()

# %% [markdown]
# According to the correlation matrix, the heating and cooling loads, as well as energy consumption, exhibit strong correlations with the overall height, orientation, and to some extent, the surface area. The orientation is considered to be an uncertain factor in building design due to limited choices compared to other variables and it plays a significant role in determining the energy efficiency of a building.

# %% [markdown]
# **3. Prepare Data**

# %%
# a) Data Cleaning
# summarize the number of unique values in each column
print(data.nunique())
# Out:
# Relative Compactness          12
# Surface Area                  12
# Roof Area                      4
# Overall Height                 2
# Orientation                    4
# Glazing Area                   4
# Glazing Area Distribution      6
# Heating Load                 586
# dtype: int64

# %%
# Identify columns with missing values and count the number of missing values
data.columns[data.isnull().any()]
print(data.isnull().sum())
# Out:
# Relative Compactness         0
# Surface Area                 0
# Roof Area                    0
# Overall Height               0
# Orientation                  0
# Glazing Area                 0
# Glazing Area Distribution    0
# Heating Load                 0
# dtype: int64

# %% [markdown]
# It is necessary to eliminate outliers in numerical data columns to improve the accuracy of training and validation processes. This can be done by determining the correlation between these columns and the target variable, identifying columns with low correlation, and then filtering out values that fall outside of the lower and upper bounds.

# %%
# calculate the correlation between numerical columns and target variables
corr_matrix = data.select_dtypes(include=np.number).corrwith(data['Heating Load']).sort_values(ascending=False)

# filter columns with low correlation
corr_threshold = 0.05
low_corr_columns = corr_matrix[corr_matrix.abs() < corr_threshold].index

# remove outliers from numerical columns with low correlation
for column in low_corr_columns:
    lower = data[column].quantile(0.01)
    upper = data[column].quantile(0.99)
    data[column] = data[column].clip(lower, upper)

# %%
# calculate the correlation between numerical columns and target variables
corr_matrix = data.select_dtypes(include=np.number).corrwith(data['Heating Load']).sort_values(ascending=False)

# filter columns with low correlation
corr_threshold = 0.05
low_corr_columns = corr_matrix[corr_matrix.abs() < corr_threshold].index

# remove outliers from numerical columns with low correlation
for column in low_corr_columns:
    lower = data[column].quantile(0.01)
    upper = data[column].quantile(0.99)
    data[column] = data[column].clip(lower, upper)

# %%
# b) Split-out dataset into train and validation sets

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=1)

print(X_train.shape, y_train.shape, X_val.shape, y_val.shape)
# Out:
# (576, 7) (576, 1) (192, 7) (192, 1)

# %%
# c) Data Transforms
# Standardize the dataset by rescaling the distribution of values

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.fit_transform(X_val)

# %% [markdown]
# **4. Evaluate Algorithms**

# %%
# a) Spot check algorithms using cross-validation technique
num_folds = 8
seed = 8

# Select 5 most popular linear and tree-based algorithms for evaluation
models = []
models.append(('LR', LinearRegression()))
models.append(('EN', ElasticNet()))
models.append(('RF', RandomForestRegressor()))
models.append(('KNN', KNeighborsRegressor()))
models.append(('SVR', MultiOutputRegressor(SVR(gamma='auto'))))
models.append(('XGBOOST', GradientBoostingRegressor()))
models.append(('ADABOOST', AdaBoostRegressor()))

# %%
# Neural Network algorithms
# create keras Sequential model
def baseline_model():
    model = Sequential()
    model.add(Dense(300, input_shape = (7, ), activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    model.add(Dense(200, activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    model.add(Dense(100, activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    model.add(Dense(1))
    # Compile model
    model.compile(optimizer = 'adam',
                loss = 'mean_squared_error',
                metrics=['mse'])
    return model

# Build model
model_NN = baseline_model()
models.append(('NN', model_NN))

# %%
# Define a callback for early stopping if the validation loss does not improve for 10 consecutive
# epochs (patience=10).
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# %%
results = []
alg_names = []

# Initialize the KerasRegressor estimator with early stopping
estimator = KerasRegressor(model=model_NN, batch_size=128, verbose=1, callbacks=[early_stopping])

for name, model in models:
    kfold = KFold(n_splits=num_folds, random_state=seed, shuffle=True)

    # modify loop for NN
    if name != 'NN':
        cvs = cross_val_score(model, X_train, y_train, cv=kfold, scoring='neg_mean_squared_error')
    else:
        validation_data = (X_val, y_val)
        cvs = cross_val_score(estimator, X_train, y_train, cv=kfold, scoring='neg_mean_squared_error', fit_params={'validation_data': validation_data, 'epochs': 150})

    results.append(cvs)
    alg_names.append(name)
    output = "%s: %f (%f)" % (name, cvs.mean(), cvs.std())
    print(output)
# Out:
# LR: -8.213543 (1.870210)
# EN: -48.528127 (10.471758)
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RF: -0.350793 (0.163337)
# KNN: -9.304752 (2.608518)
# SVR: -12.495847 (3.518934)
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\ensemble\_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\ensemble\_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\ensemble\_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\ensemble\_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\ensemble\_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\ensemble\_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\ensemble\_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\ensemble\_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# XGBOOST: -0.259107 (0.102064)
# ADABOOST: -3.890942 (0.447315)
# Epoch 1/150
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\model_selection\_validation.py:73: FutureWarning: `fit_params` is deprecated and will be removed in version 1.6. Pass parameters via `params` instead.
#   warnings.warn(
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 30 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 580.5533 - mse: 580.5533 - val_loss: 637.4835 - val_mse: 637.4835
# Epoch 2/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss:
150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 157.6095 - mse: 157.6095 - val_loss: 205.3890 - val_mse: 205.3890
# Epoch 65/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 148.2739 - mse: 148.2739 - val_loss: 199.3049 - val_mse: 199.3049
# Epoch 66/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 151.1911 - mse: 151.1911 - val_loss: 191.0336 - val_mse: 191.0336
# Epoch 67/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 133.9250 - mse: 133.9250 - val_loss: 181.2504 - val_mse: 181.2504
# Epoch 68/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 139.2314 - mse: 139.2314 - val_loss: 173.9549 - val_mse: 173.9549
# Epoch 69/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 135.3729 - mse: 135.3729 - val_loss: 166.2741 - val_mse: 166.2741
# Epoch 70/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 126.0979 - mse: 126.0979 - val_loss: 157.9051 - val_mse: 157.9051
# Epoch 71/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 124.8363 - mse: 124.8363 - val_loss: 152.0943 - val_mse: 152.0943
# Epoch 72/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 111.6842 - mse: 111.6842 - val_loss: 145.8298 - val_mse: 145.8298
# Epoch 73/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 113.6659 - mse: 113.6659 - val_loss: 137.5983 - val_mse: 137.5983
# Epoch 74/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 96.5161 - mse: 96.5161 - val_loss: 128.6635 - val_mse: 128.6635
# Epoch 75/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 95.4417 - mse: 95.4417 - val_loss: 120.3091 - val_mse: 120.3091
# Epoch 76/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 87.7508 - mse: 87.7508 - val_loss: 113.1370 - val_mse: 113.1370
# Epoch 77/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 83.6724 - mse: 83.6724 - val_loss: 107.8847 - val_mse: 107.8847
# Epoch 78/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 86.6550 - mse: 86.6550 - val_loss: 103.7487 - val_mse: 103.7487
# Epoch 79/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 80.1517 - mse: 80.1517 - val_loss: 101.4851 - val_mse: 101.4851
# Epoch 80/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 73.0861 - mse: 73.0861 - val_loss: 97.6490 - val_mse: 97.6490
# Epoch 81/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 73.5803 - mse: 73.5803 - val_loss: 94.1509 - val_mse: 94.1509
# Epoch 82/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 70.2632 - mse: 70.2632 - val_loss: 91.9126 - val_mse: 91.9126
# Epoch 83/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 63.2736 - mse: 63.2736 - val_loss: 88.4954 - val_mse: 88.4954
# Epoch 84/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 58.9609 - mse: 58.9609 - val_loss: 86.1289 - val_mse: 86.1289
# Epoch 85/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 64.7316 - mse: 64.7316 - val_loss: 83.1526 - val_mse: 83.1526
# Epoch 86/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 65.5100 - mse: 65.5100 - val_loss: 80.6262 - val_mse: 80.6262
# Epoch 87/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 51.2688 - mse: 51.2688 - val_loss: 79.5987 - val_mse: 79.5987
# Epoch 88/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 44.7626 - mse: 44.7626 - val_loss: 79.1528 - val_mse: 79.1528
# Epoch 89/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 47.1889 - mse: 47.1889 - val_loss: 76.6497 - val_mse: 76.6497
# Epoch 90/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 53.6996 - mse: 53.6996 - val_loss: 71.9946 - val_mse: 71.9946
# Epoch 91/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 40.9949 - mse: 40.9949 - val_loss: 66.5946 - val_mse: 66.5946
# Epoch 92/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 41.5022 - mse: 41.5022 - val_loss: 60.2362 - val_mse: 60.2362
# Epoch 93/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 40.3950 - mse: 40.3950 - val_loss: 53.8612 - val_mse: 53.8612
# Epoch 94/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 37.0803 - mse: 37.0803 - val_loss: 48.6092 - val_mse: 48.6092
# Epoch 95/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 34.4558 - mse: 34.4558 - val_loss: 45.3992 - val_mse: 45.3992
# Epoch 96/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 39.8663 - mse: 39.8663 - val_loss: 42.1036 - val_mse: 42.1036
# Epoch 97/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 32.9172 - mse: 32.9172 - val_loss: 39.9318 - val_mse: 39.9318
# Epoch 98/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 34.9401 - mse: 34.9401 - val_loss: 37.4500 - val_mse: 37.4500
# Epoch 99/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 31.6685 - mse: 31.6685 - val_loss: 35.1558 - val_mse: 35.1558
# Epoch 100/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 32.0820 - mse: 32.0820 - val_loss: 33.0881 - val_mse: 33.0881
# Epoch 101/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 30.3537 - mse: 30.3537 - val_loss: 30.4598 - val_mse: 30.4598
# Epoch 102/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 31.0836 - mse: 31.0836 - val_loss: 27.9602 - val_mse: 27.9602
# Epoch 103/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 28.0025 - mse: 28.0025 - val_loss: 26.1055 - val_mse: 26.1055
# Epoch 104/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.1481 - mse: 31.1481 - val_loss: 24.5368 - val_mse: 24.5368
# Epoch 105/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 26.0759 - mse: 26.0759 - val_loss: 23.3284 - val_mse: 23.3284
# Epoch 106/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27.2609 - mse: 27.2609 - val_loss: 22.4022 - val_mse: 22.4022
# Epoch 107/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 26.0230 - mse: 26.0230 - val_loss: 22.9904 - val_mse: 22.9904
# Epoch 108/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 24.0687 - mse: 24.0687 - val_loss: 23.0204 - val_mse: 23.0204
# Epoch 109/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.2868 - mse: 30.2868 - val_loss: 23.2603 - val_mse: 23.2603
# Epoch 110/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27.0625 - mse: 27.0625 - val_loss: 22.8473 - val_mse: 22.8473
# Epoch 111/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 26.3052 - mse: 26.3052 - val_loss: 22.1982 - val_mse: 22.1982
# Epoch 112/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 24.9755 - mse: 24.9755 - val_loss: 20.5508 - val_mse: 20.5508
# Epoch 113/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.5327 - mse: 23.5327 - val_loss: 18.9633 - val_mse: 18.9633
# Epoch 114/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 26.4534 - mse: 26.4534 - val_loss: 17.4410 - val_mse: 17.4410
# Epoch 115/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 25.2578 - mse: 25.2578 - val_loss: 16.4432 - val_mse: 16.4432
# Epoch 116/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.2008 - mse: 23.2008 - val_loss: 15.9195 - val_mse: 15.9195
# Epoch 117/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 25.4914 - mse: 25.4914 - val_loss: 15.5573 - val_mse: 15.5573
# Epoch 118/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.8342 - mse: 26.8342 - val_loss: 15.3009 - val_mse: 15.3009
# Epoch 119/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.8371 - mse: 22.8371 - val_loss: 14.9873 - val_mse: 14.9873
# Epoch 120/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.8931 - mse: 23.8931 - val_loss: 15.0984 - val_mse: 15.0984
# Epoch 121/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.4863 - mse: 28.4863 - val_loss: 14.3292 - val_mse: 14.3292
# Epoch 122/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.1882 - mse: 24.1882 - val_loss: 13.4564 - val_mse: 13.4564
# Epoch 123/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.2857 - mse: 22.2857 - val_loss: 13.2075 - val_mse: 13.2075
# Epoch 124/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.3100 - mse: 21.3100 - val_loss: 13.1981 - val_mse: 13.1981
# Epoch 125/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.2115 - mse: 18.2115 - val_loss: 13.0358 - val_mse: 13.0358
# Epoch 126/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.7795 - mse: 22.7795 - val_loss: 12.4464 - val_mse: 12.4464
# Epoch 127/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.1261 - mse: 22.1261 - val_loss: 11.8516 - val_mse: 11.8516
# Epoch 128/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.7984 - mse: 22.7984 - val_loss: 11.4154 - val_mse: 11.4154
# Epoch 129/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.4794 - mse: 21.4794 - val_loss: 11.6393 - val_mse: 11.6393
# Epoch 130/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.6977 - mse: 26.6977 - val_loss: 11.7204 - val_mse: 11.7204
# Epoch 131/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.0518 - mse: 21.0518 - val_loss: 11.5251 - val_mse: 11.5251
# Epoch 132/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.5263 - mse: 24.5263 - val_loss: 11.2198 - val_mse: 11.2198
# Epoch 133/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.0586 - mse: 23.0586 - val_loss: 10.5734 - val_mse: 10.5734
# Epoch 134/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.1129 - mse: 26.1129 - val_loss: 10.5122 - val_mse: 10.5122
# Epoch 135/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.0440 - mse: 21.0440 - val_loss: 10.5001 - val_mse: 10.5001
# Epoch 136/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.3515 - mse: 22.3515 - val_loss: 10.4920 - val_mse: 10.4920
# Epoch 137/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.6426 - mse: 19.6426 - val_loss: 10.5540 - val_mse: 10.5540
# Epoch 138/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.4080 - mse: 21.4080 - val_loss: 10.3319 - val_mse: 10.3319
# Epoch 139/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.4438 - mse: 21.4438 - val_loss: 10.1724 - val_mse: 10.1724
# Epoch 140/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.0915 - mse: 21.0915 - val_loss: 9.7617 - val_mse: 9.7617
# Epoch 141/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.4964 - mse: 23.4964 - val_loss: 9.4703 - val_mse: 9.4703
# Epoch 142/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 20.0094 - mse: 20.0094 - val_loss: 9.2530 - val_mse: 9.2530
# Epoch 143/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.5584 - mse: 21.5584 - val_loss: 9.2562 - val_mse: 9.2562
# Epoch 144/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.6191 - mse: 20.6191 - val_loss: 9.2978 - val_mse: 9.2978
# Epoch 145/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.0329 - mse: 20.0329 - val_loss: 9.2157 - val_mse: 9.2157
# Epoch 146/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.1533 - mse: 19.1533 - val_loss: 9.0897 - val_mse: 9.0897
# Epoch 147/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.1713 - mse: 24.1713 - val_loss: 8.8596 - val_mse: 8.8596
# Epoch 148/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.2845 - mse: 23.2845 - val_loss: 8.9019 - val_mse: 8.9019
# Epoch 149/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.0869 - mse: 20.0869 - val_loss: 9.1543 - val_mse: 9.1543
# Epoch 150/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.4523 - mse: 20.4523 - val_loss: 9.8531 - val_mse: 9.8531
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Epoch 1/150
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 30 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 559.0746 - mse: 559.0746 - val_loss: 639.2108 - val_mse: 639.2108
# Epoch 2/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 522.4938 - mse: 522.4938 - val_loss: 630.7801 - val_mse: 630.7801
# Epoch 3/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 512.9711 - mse: 512.9711 - val_loss: 621.6349 - val_mse: 621.6349
# Epoch 4/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 517.3731 - mse: 517.3731 - val_loss: 612.5957 - val_mse: 612.5957
# Epoch 5/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 507.6018 - mse: 507.6018 - val_loss: 604.5091 - val_mse: 604.5091
# Epoch 6/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 489.4625 - mse: 489.4625 - val_loss: 597.2656 - val_mse: 597.2656
# Epoch 7/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 492.4326 - mse: 492.4326 - val_loss: 590.0118 - val_mse: 590.0118
# Epoch 8/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss:
150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.5307 - mse: 34.5307 - val_loss: 30.4910 - val_mse: 30.4910
# Epoch 103/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.9925 - mse: 32.9925 - val_loss: 30.3553 - val_mse: 30.3553
# Epoch 104/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.0131 - mse: 34.0131 - val_loss: 29.1292 - val_mse: 29.1292
# Epoch 105/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.3965 - mse: 34.3965 - val_loss: 26.3689 - val_mse: 26.3689
# Epoch 106/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.5994 - mse: 29.5994 - val_loss: 24.1594 - val_mse: 24.1594
# Epoch 107/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.8448 - mse: 24.8448 - val_loss: 22.3014 - val_mse: 22.3014
# Epoch 108/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.3235 - mse: 29.3235 - val_loss: 20.8054 - val_mse: 20.8054
# Epoch 109/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.7319 - mse: 23.7319 - val_loss: 19.2319 - val_mse: 19.2319
# Epoch 110/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.8987 - mse: 26.8987 - val_loss: 18.3187 - val_mse: 18.3187
# Epoch 111/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.6228 - mse: 26.6228 - val_loss: 17.9889 - val_mse: 17.9889
# Epoch 112/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.4452 - mse: 26.4452 - val_loss: 17.6486 - val_mse: 17.6486
# Epoch 113/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.4103 - mse: 24.4103 - val_loss: 17.4079 - val_mse: 17.4079
# Epoch 114/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27.5444 - mse: 27.5444 - val_loss: 17.5354 - val_mse: 17.5354
# Epoch 115/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.9034 - mse: 23.9034 - val_loss: 17.8363 - val_mse: 17.8363
# Epoch 116/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.5081 - mse: 23.5081 - val_loss: 17.1737 - val_mse: 17.1737
# Epoch 117/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.6024 - mse: 23.6024 - val_loss: 16.3517 - val_mse: 16.3517
# Epoch 118/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 25.2880 - mse: 25.2880 - val_loss: 15.0826 - val_mse: 15.0826
# Epoch 119/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.6916 - mse: 20.6916 - val_loss: 14.4717 - val_mse: 14.4717
# Epoch 120/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.9175 - mse: 25.9175 - val_loss: 14.2899 - val_mse: 14.2899
# Epoch 121/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.5497 - mse: 24.5497 - val_loss: 14.2320 - val_mse: 14.2320
# Epoch 122/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.1572 - mse: 28.1572 - val_loss: 14.3546 - val_mse: 14.3546
# Epoch 123/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.7995 - mse: 19.7995 - val_loss: 13.5266 - val_mse: 13.5266
# Epoch 124/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.4006 - mse: 19.4006 - val_loss: 12.8501 - val_mse: 12.8501
# Epoch 125/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.8205 - mse: 23.8205 - val_loss: 12.7639 - val_mse: 12.7639
# Epoch 126/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.9828 - mse: 23.9828 - val_loss: 12.4500 - val_mse: 12.4500
# Epoch 127/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.2918 - mse: 23.2918 - val_loss: 11.8642 - val_mse: 11.8642
# Epoch 128/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.6990 - mse: 21.6990 - val_loss: 11.2599 - val_mse: 11.2599
# Epoch 129/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.4406 - mse: 19.4406 - val_loss: 10.9610 - val_mse: 10.9610
# Epoch 130/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.7128 - mse: 20.7128 - val_loss: 11.2581 - val_mse: 11.2581
# Epoch 131/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.8773 - mse: 22.8773 - val_loss: 11.8377 - val_mse: 11.8377
# Epoch 132/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.7538 - mse: 21.7538 - val_loss: 11.7713 - val_mse: 11.7713
# Epoch 133/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.9476 - mse: 18.9476 - val_loss: 11.2755 - val_mse: 11.2755
# Epoch 134/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 24.5662 - mse: 24.5662 - val_loss: 11.1670 - val_mse: 11.1670
# Epoch 135/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20
150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 66.7921 - mse: 66.7921 - val_loss: 97.7929 - val_mse: 97.7929
# Epoch 81/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 65.7253 - mse: 65.7253 - val_loss: 93.3801 - val_mse: 93.3801
# Epoch 82/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 69.3820 - mse: 69.3820 - val_loss: 87.0406 - val_mse: 87.0406
# Epoch 83/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 58.4092 - mse: 58.4092 - val_loss: 81.5611 - val_mse: 81.5611
# Epoch 84/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 59.7296 - mse: 59.7296 - val_loss: 76.8647 - val_mse: 76.8647
# Epoch 85/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 50.8858 - mse: 50.8858 - val_loss: 72.7206 - val_mse: 72.7206
# Epoch 86/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 55.9916 - mse: 55.9916 - val_loss: 68.0606 - val_mse: 68.0606
# Epoch 87/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 54.4554 - mse: 54.4554 - val_loss: 64.9352 - val_mse: 64.9352
# Epoch 88/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 51.9536 - mse: 51.9536 - val_loss: 62.2569 - val_mse: 62.2569
# Epoch 89/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 47.0853 - mse: 47.0853 - val_loss: 61.1013 - val_mse: 61.1013
# Epoch 90/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 45.5947 - mse: 45.5947 - val_loss: 60.4700 - val_mse: 60.4700
# Epoch 91/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 40.3235 - mse: 40.3235 - val_loss: 60.1272 - val_mse: 60.1272
# Epoch 92/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 44.6971 - mse: 44.6971 - val_loss: 55.8995 - val_mse: 55.8995
# Epoch 93/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 39.3473 - mse: 39.3473 - val_loss: 53.6048 - val_mse: 53.6048
# Epoch 94/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 37.2780 - mse: 37.2780 - val_loss: 51.9269 - val_mse: 51.9269
# Epoch 95/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 39.8678 - mse: 39.8678 - val_loss: 48.3842 - val_mse: 48.3842
# Epoch 96/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 38.2983 - mse: 38.2983 - val_loss: 46.3246 - val_mse: 46.3246
# Epoch 97/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 37.4245 - mse: 37.4245 - val_loss: 44.8891 - val_mse: 44.8891
# Epoch 98/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.5333 - mse: 31.5333 - val_loss: 42.2446 - val_mse: 42.2446
# Epoch 99/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.5524 - mse: 28.5524 - val_loss: 38.7927 - val_mse: 38.7927
# Epoch 100/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.3673 - mse: 30.3673 - val_loss: 34.8775 - val_mse: 34.8775
# Epoch 101/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.2490 - mse: 31.2490 - val_loss: 33.3974 - val_mse: 33.3974
# Epoch 102/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.0502 - mse: 27.0502 - val_loss: 33.1671 - val_mse: 33.1671
# Epoch 103/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.0420 - mse: 26.0420 - val_loss: 32.4965 - val_mse: 32.4965
# Epoch 104/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.2806 - mse: 28.2806 - val_loss: 30.9852 - val_mse: 30.9852
# Epoch 105/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.3995 - mse: 28.3995 - val_loss: 29.5966 - val_mse: 29.5966
# Epoch 106/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.6871 - mse: 23.6871 - val_loss: 27.9716 - val_mse: 27.9716
# Epoch 107/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.0107 - mse: 26.0107 - val_loss: 27.4922 - val_mse: 27.4922
# Epoch 108/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.6425 - mse: 28.6425 - val_loss: 26.6280 - val_mse: 26.6280
# Epoch 109/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.7838 - mse: 25.7838 - val_loss: 26.9985 - val_mse: 26.9985
# Epoch 110/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.0820 - mse: 29.0820 - val_loss: 25.9729 - val_mse: 25.9729
# Epoch 111/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.0003 - mse: 23.0003 - val_loss: 25.5385 - val_mse: 25.5385
# Epoch 112/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.6619 - mse: 22.6619 - val_loss: 23.9723 - val_mse: 23.9723
# Epoch 113/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.9831 - mse: 27.9831 - val_loss: 21.5832 - val_mse: 21.5832
# Epoch 114/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.9879 - mse: 24.9879 - val_loss: 19.0765 - val_mse: 19.0765
# Epoch 115/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.6899 - mse: 22.6899 - val_loss: 18.6012 - val_mse: 18.6012
# Epoch 116/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.5341 - mse: 23.5341 - val_loss: 19.2502 - val_mse: 19.2502
# Epoch 117/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.0610 - mse: 27.0610 - val_loss: 19.6988 - val_mse: 19.6988
# Epoch 118/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.4993 - mse: 22.4993 - val_loss: 19.4727 - val_mse: 19.4727
# Epoch 119/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.7139 - mse: 22.7139 - val_loss: 18.3971 - val_mse: 18.3971
# Epoch 120/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.7425 - mse: 23.7425 - val_loss: 17.4645 - val_mse: 17.4645
# Epoch 121/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.6287 - mse: 20.6287 - val_loss: 16.7785 - val_mse: 16.7785
# Epoch 122/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.5483 - mse: 26.5483 - val_loss: 16.0831 - val_mse: 16.0831
# Epoch 123/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.2824 - mse: 25.2824 - val_loss: 15.9390 - val_mse: 15.9390
# Epoch 124/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.7427 - mse: 26.7427 - val_loss: 15.1479 - val_mse: 15.1479
# Epoch 125/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.7539 - mse: 22.7539 - val_loss: 13.9515 - val_mse: 13.9515
# Epoch 126/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.9527 - mse: 22.9527 - val_loss: 13.4808 - val_mse: 13.4808
# Epoch 127/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.8005 - mse: 19.8005 - val_loss: 13.1297 - val_mse: 13.1297
# Epoch 128/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.6805 - mse: 23.6805 - val_loss: 13.4165 - val_mse: 13.4165
# Epoch 129/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.8584 - mse: 22.8584 - val_loss: 13.3593 - val_mse: 13.3593
# Epoch 130/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.0676 - mse: 19.0676 - val_loss: 13.1812 - val_mse: 13.1812
# Epoch 131/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.3056 - mse: 23.3056 - val_loss: 12.8132 - val_mse: 12.8132
# Epoch 132/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.2500 - mse: 22.2500 - val_loss: 13.1673 - val_mse: 13.1673
# Epoch 133/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.5706 - mse: 21.5706 - val_loss: 13.7093 - val_mse: 13.7093
# Epoch 134/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.7110 - mse: 22.7110 - val_loss: 14.0403 - val_mse: 14.0403
# Epoch 135/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.4849 - mse: 20.4849 - val_loss: 14.1314 - val_mse: 14.1314
# Epoch 136/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.4332 - mse: 22.4332 - val_loss: 13.9398 - val_mse: 13.9398
# Epoch 137/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.2040 - mse: 21.2040 - val_loss: 13.1176 - val_mse: 13.1176
# Epoch 138/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.6128 - mse: 23.6128 - val_loss: 12.2606 - val_mse: 12.2606
# Epoch 139/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.5329 - mse: 19.5329 - val_loss: 11.7709 - val_mse: 11.7709
# Epoch 140/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.1893 - mse: 21.1893 - val_loss: 11.4972 - val_mse: 11.4972
# Epoch 141/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.9741 - mse: 19.9741 - val_loss: 11.1190 - val_mse: 11.1190
# Epoch 142/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.3341 - mse: 23.3341 - val_loss: 10.7528 - val_mse: 10.7528
# Epoch 143/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.9072 - mse: 19.9072 - val_loss: 10.8232 - val_mse: 10.8232
# Epoch 144/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.8010 - mse: 17.8010 - val_loss: 11.3365 - val_mse: 11.3365
# Epoch 145/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 20
# Epoch 143/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.0520 - mse: 20.0520 - val_loss: 8.6949 - val_mse: 8.6949
# Epoch 144/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.3021 - mse: 19.3021 - val_loss: 8.5594 - val_mse: 8.5594
# Epoch 145/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.9383 - mse: 21.9383 - val_loss: 8.5320 - val_mse: 8.5320
# Epoch 146/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.9323 - mse: 19.9323 - val_loss: 8.4742 - val_mse: 8.4742
# Epoch 147/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.2688 - mse: 18.2688 - val_loss: 8.4024 - val_mse: 8.4024
# Epoch 148/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.6230 - mse: 19.6230 - val_loss: 8.2832 - val_mse: 8.2832
# Epoch 149/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.8052 - mse: 21.8052 - val_loss: 8.0889 - val_mse: 8.0889
# Epoch 150/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.2372 - mse: 17.2372 - val_loss: 8.0424 - val_mse: 8.0424
# Epoch 151/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.7334 - mse: 18.7334 - val_loss: 8.1743 - val_mse: 8.1743
# Epoch 152/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.2993 - mse: 20.2993 - val_loss: 8.2249 - val_mse: 8.2249
# Epoch 153/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.1335 - mse: 20.1335 - val_loss: 8.1639 - val_mse: 8.1639
# Epoch 154/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.3227 - mse: 16.3227 - val_loss: 8.3149 - val_mse: 8.3149
# Epoch 155/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.8030 - mse: 17.8030 - val_loss: 8.5046 - val_mse: 8.5046
# Epoch 156/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.7564 - mse: 17.7564 - val_loss: 8.3833 - val_mse: 8.3833
# Epoch 157/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.0016 - mse: 18.0016 - val_loss: 8.2099 - val_mse: 8.2099
# Epoch 158/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.1794 - mse: 20.1794 - val_loss: 8.1656 - val_mse: 8.1656
# Epoch 159/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.6550 - mse: 17.6550 - val_loss: 8.3733 - val_mse: 8.3733
# Epoch 160/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.5589 - mse: 17.5589 - val_loss: 8.0749 - val_mse: 8.0749

# %%
display(pd.DataFrame(results))
# Out:
#         0       1       2       3       4       5       6       7
# 0  -5.619 -11.217  -8.893  -6.969  -6.699  -8.609  -6.986 -10.715
# 1 -35.356 -53.013 -63.818 -43.076 -42.443 -57.107 -34.400 -59.012
# 2  -0.245  -0.236  -0.314  -0.731  -0.183  -0.301  -0.334  -0.463
# 3  -7.020 -12.859 -11.114  -6.642  -6.138  -8.877  -8.555 -13.234
# 4  -8.854 -13.257 -15.512  -8.223 -10.383 -15.876  -9.579 -18.281
# 5  -0.205  -0.171  -0.241  -0.362  -0.226  -0.190  -0.193  -0.486
# 6  -3.116  -4.067  -3.339  -4.162  -3.781  -3.821  -4.503  -4.338
# 7  -6.515 -10.476  -9.645  -4.851  -8.196  -7.726  -7.101 -13.027
# 8  -5.975  -9.466  -8.764  -4.815  -6.247  -8.176  -6.685 -11.886

# %%
# b) Compare algorithms and the NN model
# Distribution of accuracy values calculated across 8 cross-validation folds.
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot()
plt.boxplot(results)
ax.set_xticklabels(alg_names)
plt.ylabel("MSE")
plt.show()

# %% [markdown]
# The Random Forest algorithm demonstrated superior performance compared to the other five machine learning algorithms and the neural network model.

# %% [markdown]
# In a regression problem, it is common to use the mean error as a measure of validation. This is done by first calculating the mean absolute error (MAE) of the test data with the mean of dataset, and then calculating the MAE of the test data with the predicted data.

# %%
# Evaluate performance of Random Forest algorithm on validation data
model_RF = RandomForestRegressor()
model_RF.fit(X_train, y_train)
y_pred_RF = model_RF.predict(X_val)
mae_pred_RF = mean_absolute_error(y_val, y_pred_RF)
print("Mean Absolute Error of predicted data: ", mae_pred_RF)
# Out:
# Mean Absolute Error of predicted data:  0.38828906250000017
# c:\Users\pkastner\anaconda3\envs\24-fa-energyinbuildings-commercial\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
# Evaluate performance of NN algorithm on validation data
model_NN.fit(X_train, y_train)
y_pred_NN = model_NN.predict(X_val)
print(y_pred_NN.shape)
mae_pred_NN = mean_absolute_error(y_val, y_pred_NN)
print("Mean Absolute Error of predicted data: ", mae_pred_NN)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 20.6038 - mse: 20.6038
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# (192, 1)
# Mean Absolute Error of predicted data:  1.7098619004090627

# %%
# Define baseline mean_absolute_error of y_val in the data set
y_mean = np.mean(y)
y_mean = np.array([y_mean]*len(y_val))
mae_ori = mean_absolute_error(y_val, y_mean)
print("Mean Absolute Error of original data: ", mae_ori)
# Out:
# Mean Absolute Error of original data:  9.156708306206598

# %% [markdown]
# The resulting MAE values show that Random Forest looks better than neural network model in prediction performance. For the sake of simplicity, I selected Random Forest as the surrogate model for the multi-objective optimization process.

# %% [markdown]
# **5. Finalize Model**

# %%
# a) Get best model parameters
model_params = model_RF.get_params()

# Print the model's parameters
print(model_params)
# Out:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %%
fig, ax = plt.subplots(figsize=(10, 5))

# Plot the actual and predicted heating load
ax.bar(np.arange(len(y_val)), y_val.iloc[:, 0], label='Actual heating load', color='orange')
ax.scatter(np.arange(len(y_pred_RF)), y_pred_RF, label='Predicted data', color='red')
ax.set_ylabel('Heating Load')
ax.legend()

# Show the plot
plt.show()

# %%
from joblib import dump

# Save the scikit-learn model to disk
filename = 'finalized_model_multivariate.joblib'
filename_scaler = 'scaler.joblib'
dump(model_RF, filename)
dump(scaler, filename_scaler)
# Out:
# ['scaler.joblib']

# %% [markdown]
# **6. Conclusions**

# %% [markdown]
# - Exploratory data analysis indicates that most input variables exhibit non-Gaussian distribution.
#
# - Based on our evaluation of five machine learning algorithms and a neural network model, we selected Random Forest as the surrogate model for multi-objective optimization due to its high score in cross validation and low Mean Squared Error values.
#
# - The Mean Absolute Error values suggest that the prediction accuracy is generally good, although the ElasticNet algorithm may require further refinement.
#
# - The results indicate that the performance of the Keras Sequential neural network model is comparable to that of other machine learning algorithms, and further hyperparameter tuning may improve its predictive accuracy.

# %%
from joblib import load

# Load the scikit-learn model from disk
filename = 'finalized_model_multivariate.joblib'
filename_scaler = 'scaler.joblib'
model_RF = load(filename)
scaler = load(filename_scaler)

# %%
# Define the input data as a dictionary
input_data = {
    'Relative Compactness': [0.98],
    'Surface Area': [600],
    'Roof Area': [120],
    'Overall Height': [20],
    'Orientation':  [135],
    'Glazing Area':  [23],
    'Glazing Area Distribution': [7]
}

# Create a DataFrame
X_new = pd.DataFrame(input_data)

# Apply the scaler to the input data
X_new_scaled = scaler.transform(X_new)
X_new_scaled
# Out:
# array([[ 1.        ,  0.29081633,  0.08843537,  4.71428571, 44.33333333,
#         57.5       ,  1.4       ]])

# %%
# Make predictions
predictions = model_RF.predict(X_new_scaled)

# Print the prediction
print('Predicted heating load:', round(predictions[0],1), "kWh")
# Out:
# Predicted heating load: 33.7 kWh
